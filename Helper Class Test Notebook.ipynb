# %%
from ClassficationMetrics import ClassificationMetrics

# %%
tn = 904
fp = 542
fn = 137
tp = 258

metrics = ClassificationMetrics(tn, fp, fn, tp)

# %%
metrics.print_all_metrics()
# Out:
# Recall/Senstivity Rate :  77.797
# Precision Rate :  86.84
# Accuracy :  0.008
# F1-Score / F Measure / Sorensen-Dice Index : 0.821
# Mathews Correlation Coefficients : 0.561
# Type I Error/(alpha)/Fall Out/False Positive Rate :  20.177
# Type II Error/(beta)/False Negative Rate : 22.203
# True Discovery Rate : 32.25
# False Discovery Rate : 13.16
# Negative Predictive Rate : 67.75
# Specificity / True Negative Rate : 79.823

# %%
from LinearRegressionV2 import LinearRegressionV2
from sklearn.datasets import make_regression

X, y = make_regression(n_samples=100, n_features=1, noise=0.4, bias=20)
# invoke the class
linreg = LinearRegressionV2(X, y, alpha=0.005, enableVisualization=True)
# Out:
# Cost:  [ 206188.55289175]
# Cost:  [ 55151.58752618]
# Cost:  [ 15690.49011469]
# Cost:  [ 4772.39063639]
# Cost:  [ 1549.02452116]
# Cost:  [ 533.6887361]
# Cost:  [ 195.09294384]
# Cost:  [ 76.99186011]
# Cost:  [ 34.44558346]
# Cost:  [ 18.78063499]
# Cost:  [ 12.93149779]
# Cost:  [ 10.72822249]
# Cost:  [ 9.89379501]
# Cost:  [ 9.57674247]
# Cost:  [ 9.45603562]
# Cost:  [ 9.41002608]
# Cost:  [ 9.39247627]
# Cost:  [ 9.38577924]
# Cost:  [ 9.38322301]
# Cost:  [ 9.38224715]
# Cost:  [ 9.38187457]
# Cost:  [ 9.38173232]
# Cost:  [ 9.38167801]
# Cost:  [ 9.38165727]
# Cost:  [ 9.38164935]
# Cost:  [ 9.38164632]
# Cost:  [ 9.38164517]
# Cost:  [ 9.38164473]
# Cost:  [ 9.38164456]
# Cost:  [ 9.3816445]
# Cost:  [ 9.38164447]
# Cost:  [ 9.38164446]
# Cost:  [ 9.38164446]
# Cost:  [ 9.38164446]
# Cost:  [ 9.38164446]
# Cost:  [ 9.38164446]
# Cost:  [ 9.38164446]
# Cost:  [ 9.38164446]
# Cost:  [ 9.38164446]
